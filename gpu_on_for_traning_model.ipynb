# %%
# conda activate tf210
import tensorflow as tf
print(tf.__version__)
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
from PIL import Image
print(Image.__file__)

# %%
#!pip install tensorflow matplotlib opencv-python pandas
# !pip install opencv-python matplotlib pandas numpy
# !pip install Pillow
#!pip install scipy
#!pip install scikit-learn
#!pip install seaborn

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils import class_weight

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils import class_weight

print(f"TensorFlow version: {tf.__version__}")
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU devices:", tf.config.list_physical_devices('GPU'))

# PARAMETERS
img_size = (280, 280)
batch_size = 32
epochs_initial = 20
epochs_finetune = 10

train_dir = './train'   # flat folder with labeled filenames like Autistic_001.jpg
valid_dir = './valid'   # has subfolders: 'Autistic', 'Non_Autistic'

# Helper to get label from filename prefix
def get_label(fname):
    fname = fname.lower()
    if fname.startswith('autistic'):
        return 0
    elif fname.startswith('non_autistic'):
        return 1
    else:
        return None

# Prepare training data lists
train_filenames = []
train_labels = []
print("Loading training filenames and labels...")
for fname in os.listdir(train_dir):
    label = get_label(fname)
    if label is not None:
        train_filenames.append(fname)
        train_labels.append(label)
print(f"Loaded {len(train_filenames)} training samples.")

# Face detection setup
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_and_crop_face(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Warning: Could not read image {img_path}")
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4)
    if len(faces) == 0:
        return None
    faces = sorted(faces, key=lambda x: x[2]*x[3], reverse=True)
    (x, y, w, h) = faces[0]
    face_img = img[y:y+h, x:x+w]
    face_img = cv2.resize(face_img, img_size)
    return cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)

# Custom train generator
def train_generator(filenames, labels, directory, datagen, batch_size, shuffle=True):
    n = len(filenames)
    indices = np.arange(n)
    while True:
        if shuffle:
            np.random.shuffle(indices)
        for start in range(0, n, batch_size):
            end = min(start + batch_size, n)
            batch_idx = indices[start:end]
            batch_imgs = []
            batch_lbls = []
            for i in batch_idx:
                img_path = os.path.join(directory, filenames[i])
                face_img = detect_and_crop_face(img_path)
                if face_img is None:
                    img = tf.keras.preprocessing.image.load_img(img_path, target_size=img_size)
                    face_img = np.array(img)
                batch_imgs.append(face_img)
                batch_lbls.append(labels[i])
            batch_imgs = np.array(batch_imgs, dtype=np.float32)
            batch_imgs = preprocess_input(batch_imgs)
            batch_imgs = datagen.standardize(batch_imgs)
            yield batch_imgs, np.array(batch_lbls)

# Strong data augmentation for training
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

print("Creating training generator...")
train_gen = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)

print("Creating validation generator...")
valid_gen = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

train_steps = len(train_filenames) // batch_size
valid_steps = valid_gen.samples // batch_size

print(f"Train steps per epoch: {train_steps}")
print(f"Validation steps: {valid_steps}")

# Calculate class weights to address imbalance
print("Calculating class weights...")
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))
print("Class weights:", class_weight_dict)

# Build model
input_layer = Input(shape=img_size + (3,))
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_layer)

for layer in base_model.layers:
    layer.trainable = False  # Freeze all layers initially

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=input_layer, outputs=output)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1)

print("Starting initial training...")
history = model.fit(
    train_gen,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_initial,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)

print("Initial training complete.")
print("Unfreezing last 10 layers of ResNet50 for fine-tuning...")

# Unfreeze last 10 layers for fine-tuning
for layer in base_model.layers[-10:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

print("Starting fine-tuning...")
history_finetune = model.fit(
    train_gen,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_finetune,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)

print("Fine-tuning complete.")

# Plot training history function
def plot_training(history):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy over epochs')

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss over epochs')

    plt.show()

plot_training(history)
plot_training(history_finetune)

# Validation evaluation
print("Evaluating on validation set...")
val_preds_prob = model.predict(valid_gen, steps=valid_steps, verbose=1)
val_preds = (val_preds_prob > 0.5).astype(int).flatten()
val_true = valid_gen.classes
val_filenames = valid_gen.filenames
class_names = list(valid_gen.class_indices.keys())

correct_idx = np.where(val_preds == val_true)[0]
wrong_idx = np.where(val_preds != val_true)[0]

print(f"Validation samples: {len(val_true)}")
print(f"Correct predictions: {len(correct_idx)}")
print(f"Wrong predictions: {len(wrong_idx)}")

def plot_examples(indices, title, max_imgs=10):
    plt.figure(figsize=(20,4))
    for i, idx in enumerate(indices[:max_imgs]):
        img_path = os.path.join(valid_dir, val_filenames[idx])
        img = plt.imread(img_path)
        plt.subplot(1, max_imgs, i+1)
        plt.imshow(img)
        plt.title(f"Pred: {class_names[val_preds[idx]]}\nTrue: {class_names[val_true[idx]]}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

plot_examples(correct_idx, "Correct Predictions")
plot_examples(wrong_idx, "Wrong Predictions")

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report

print(f"TensorFlow version: {tf.__version__}")
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU devices:", tf.config.list_physical_devices('GPU'))

# PARAMETERS
img_size = (280, 280)
batch_size = 32
epochs_initial = 20
epochs_finetune = 10

train_dir = './train'   # flat folder with labeled filenames like Autistic_001.jpg
valid_dir = './valid'   # has subfolders: 'Autistic', 'Non_Autistic'

# Helper to get label from filename prefix
def get_label(fname):
    fname = fname.lower()
    if fname.startswith('autistic'):
        return 0
    elif fname.startswith('non_autistic'):
        return 1
    else:
        return None

# Prepare training data lists
train_filenames = []
train_labels = []
print("Loading training filenames and labels...")
for fname in os.listdir(train_dir):
    label = get_label(fname)
    if label is not None:
        train_filenames.append(fname)
        train_labels.append(label)
print(f"Loaded {len(train_filenames)} training samples.")

# Face detection setup
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_and_crop_face(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Warning: Could not read image {img_path}")
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4)
    if len(faces) == 0:
        return None
    faces = sorted(faces, key=lambda x: x[2]*x[3], reverse=True)
    (x, y, w, h) = faces[0]
    face_img = img[y:y+h, x:x+w]
    face_img = cv2.resize(face_img, img_size)
    return cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)

# Custom train generator
def train_generator(filenames, labels, directory, datagen, batch_size, shuffle=True):
    n = len(filenames)
    indices = np.arange(n)
    while True:
        if shuffle:
            np.random.shuffle(indices)
        for start in range(0, n, batch_size):
            end = min(start + batch_size, n)
            batch_idx = indices[start:end]
            batch_imgs = []
            batch_lbls = []
            for i in batch_idx:
                img_path = os.path.join(directory, filenames[i])
                face_img = detect_and_crop_face(img_path)
                if face_img is None:
                    img = tf.keras.preprocessing.image.load_img(img_path, target_size=img_size)
                    face_img = np.array(img)
                batch_imgs.append(face_img)
                batch_lbls.append(labels[i])
            batch_imgs = np.array(batch_imgs, dtype=np.float32)
            batch_imgs = preprocess_input(batch_imgs)
            batch_imgs = datagen.standardize(batch_imgs)
            yield batch_imgs, np.array(batch_lbls)

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

print("Creating training generator...")
train_gen = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)

print("Creating validation generator...")
valid_gen = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

train_steps = len(train_filenames) // batch_size
valid_steps = valid_gen.samples // batch_size

print(f"Train steps per epoch: {train_steps}")
print(f"Validation steps: {valid_steps}")

# Calculate class weights to address imbalance
print("Calculating class weights...")
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))
print("Class weights:", class_weight_dict)

# Build model
input_layer = Input(shape=img_size + (3,))
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_layer)

for layer in base_model.layers:
    layer.trainable = False  # Freeze all layers initially

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=input_layer, outputs=output)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1)

print("Starting initial training...")
train_gen_initial = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)
history = model.fit(
    train_gen_initial,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_initial,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)

print("Initial training complete.")
print("Unfreezing last 10 layers of ResNet50 for fine-tuning...")

# Unfreeze last 10 layers for fine-tuning
for layer in base_model.layers[-10:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

print("Starting fine-tuning...")
train_gen_finetune = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)
history_finetune = model.fit(
    train_gen_finetune,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_finetune,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)


print("Fine-tuning complete.")

# Plot training history function
def plot_training(history, title_prefix=''):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title(f'{title_prefix} Accuracy over epochs')

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title(f'{title_prefix} Loss over epochs')

    plt.show()

plot_training(history, "Initial Training")
plot_training(history_finetune, "Fine-Tuning")

# Validation evaluation
print("Evaluating on validation set...")
valid_gen.reset()  # Reset generator before prediction

val_preds_prob = model.predict(valid_gen, steps=valid_steps, verbose=1)
val_preds = (val_preds_prob > 0.5).astype(int).flatten()
val_true = valid_gen.classes
val_filenames = valid_gen.filenames
class_names = list(valid_gen.class_indices.keys())

correct_idx = np.where(val_preds == val_true)[0]
wrong_idx = np.where(val_preds != val_true)[0]

print(f"Validation samples: {len(val_true)}")
print(f"Correct predictions: {len(correct_idx)}")
print(f"Wrong predictions: {len(wrong_idx)}")

# Confusion matrix
cm = confusion_matrix(val_true, val_preds)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix on Validation Set')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(val_true, val_preds, target_names=class_names))

# Correlation matrix of true vs predicted labels (for binary just confusion matrix correlation)
correlation = np.corrcoef(val_true, val_preds)[0,1]
print(f"Correlation coefficient between true and predicted labels: {correlation:.4f}")

# Plot examples function
def plot_examples(indices, title, max_imgs=10):
    plt.figure(figsize=(20,4))
    for i, idx in enumerate(indices[:max_imgs]):
        img_path = os.path.join(valid_dir, val_filenames[idx])
        img = plt.imread(img_path)
        plt.subplot(1, max_imgs, i+1)
        plt.imshow(img)
        plt.title(f"Pred: {class_names[val_preds[idx]]}\nTrue: {class_names[val_true[idx]]}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

plot_examples(correct_idx, "Correct Predictions")
plot_examples(wrong_idx, "Wrong Predictions")

# %%
#Cell 1: Setup & Training
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils import class_weight

print(f"TensorFlow version: {tf.__version__}")
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU devices:", tf.config.list_physical_devices('GPU'))

# Parameters
img_size = (280, 280)
batch_size = 32
epochs_initial = 20
epochs_finetune = 10

train_dir = './train'   
valid_dir = './valid'   

# Label helper
def get_label(fname):
    fname = fname.lower()
    if fname.startswith('autistic'):
        return 0
    elif fname.startswith('non_autistic'):
        return 1
    else:
        return None

# Prepare train filenames and labels
train_filenames = []
train_labels = []
for fname in os.listdir(train_dir):
    label = get_label(fname)
    if label is not None:
        train_filenames.append(fname)
        train_labels.append(label)
print(f"Loaded {len(train_filenames)} training samples.")

# Face detection cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detect_and_crop_face(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Warning: Could not read image {img_path}")
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4)
    if len(faces) == 0:
        return None
    faces = sorted(faces, key=lambda x: x[2]*x[3], reverse=True)
    (x, y, w, h) = faces[0]
    face_img = img[y:y+h, x:x+w]
    face_img = cv2.resize(face_img, img_size)
    return cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)

def train_generator(filenames, labels, directory, datagen, batch_size, shuffle=True):
    n = len(filenames)
    indices = np.arange(n)
    while True:
        if shuffle:
            np.random.shuffle(indices)
        for start in range(0, n, batch_size):
            end = min(start + batch_size, n)
            batch_idx = indices[start:end]
            batch_imgs, batch_lbls = [], []
            for i in batch_idx:
                img_path = os.path.join(directory, filenames[i])
                face_img = detect_and_crop_face(img_path)
                if face_img is None:
                    img = tf.keras.preprocessing.image.load_img(img_path, target_size=img_size)
                    face_img = np.array(img)
                batch_imgs.append(face_img)
                batch_lbls.append(labels[i])
            batch_imgs = np.array(batch_imgs, dtype=np.float32)
            batch_imgs = preprocess_input(batch_imgs)
            batch_imgs = datagen.standardize(batch_imgs)
            yield batch_imgs, np.array(batch_lbls)

# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_steps = len(train_filenames) // batch_size

print("Creating generators...")
train_gen = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)

valid_gen = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

valid_steps = valid_gen.samples // batch_size

# Class weights
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))
print("Class weights:", class_weight_dict)

# Model building
input_layer = Input(shape=img_size + (3,))
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_layer)
for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1)

print("Starting initial training...")
history = model.fit(
    train_gen,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_initial,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)

print("Initial training complete.")

# Unfreeze last 10 layers for fine-tuning
print("Unfreezing last 10 layers for fine-tuning...")
for layer in base_model.layers[-10:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

print("Starting fine-tuning...")
train_gen_finetune = train_generator(train_filenames, train_labels, train_dir, train_datagen, batch_size)
history_finetune = model.fit(
    train_gen_finetune,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=valid_steps,
    epochs=epochs_finetune,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    workers=1,
    use_multiprocessing=False
)

print("Fine-tuning complete.")
model.save('model.h5')
# Out:
# TensorFlow version: 2.10.0
# Num GPUs Available: 1
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Loaded 2540 training samples.
# Creating generators...
# Found 100 images belonging to 2 classes.
# Class weights: {0: 1.0, 1: 1.0}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 280, 280, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 286, 286, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 140, 140, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 140, 140, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 140, 140, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 142, 142, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 70, 70, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 70, 70, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 70, 70, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 70, 70, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 70, 70, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 70, 70, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 70, 70, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 70, 70, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 70, 70, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 70, 70, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 70, 70, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 70, 70, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 70, 70, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 70, 70, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 70, 70, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 70, 70, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 70, 70, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 70, 70, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 70, 70, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 70, 70, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 70, 70, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 70, 70, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 70, 70, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 35, 35, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 35, 35, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 35, 35, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 35, 35, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 35, 35, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 35, 35, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 35, 35, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 35, 35, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 35, 35, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 35, 35, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 35, 35, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 35, 35, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 35, 35, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 35, 35, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 35, 35, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 35, 35, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 35, 35, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 35, 35, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 35, 35, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 35, 35, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 35, 35, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 35, 35, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 35, 35, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 35, 35, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 35, 35, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 35, 35, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 35, 35, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 35, 35, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 18, 18, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 18, 18, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 18, 18, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 18, 18, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 18, 18, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 9, 9, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 9, 9, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          1049088     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization (BatchNorm  (None, 512)         2048        ['dense[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 512)          0           ['batch_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 1)            513         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 24,639,361
# Trainable params: 1,050,625
# Non-trainable params: 23,588,736
# __________________________________________________________________________________________________
# Starting initial training...
# Epoch 1/20
# 79/79 [==============================] - 45s 510ms/step - loss: 0.6738 - accuracy: 0.6756 - val_loss: 0.5038 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Epoch 2/20
# 79/79 [==============================] - 39s 501ms/step - loss: 0.5061 - accuracy: 0.7679 - val_loss: 0.4838 - val_accuracy: 0.7708 - lr: 1.0000e-04
# Epoch 3/20
# 79/79 [==============================] - 40s 511ms/step - loss: 0.4457 - accuracy: 0.7947 - val_loss: 0.4826 - val_accuracy: 0.7917 - lr: 1.0000e-04
# Epoch 4/20
# 79/79 [==============================] - 41s 523ms/step - loss: 0.3966 - accuracy: 0.8206 - val_loss: 0.4792 - val_accuracy: 0.8229 - lr: 1.0000e-04
# Epoch 5/20
# 79/79 [==============================] - 40s 513ms/step - loss: 0.3945 - accuracy: 0.8270 - val_loss: 0.4754 - val_accuracy: 0.8021 - lr: 1.0000e-04
# Epoch 6/20
# 79/79 [==============================] - 41s 520ms/step - loss: 0.3448 - accuracy: 0.8517 - val_loss: 0.4893 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 7/20
# 79/79 [==============================] - 40s 510ms/step - loss: 0.3251 - accuracy: 0.8561 - val_loss: 0.4909 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 8/20
# 79/79 [==============================] - 40s 505ms/step - loss: 0.3027 - accuracy: 0.8616 - val_loss: 0.4775 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 9/20
# 79/79 [==============================] - 40s 513ms/step - loss: 0.2724 - accuracy: 0.8804 - val_loss: 0.5061 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 10/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.8947
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 79/79 [==============================] - 40s 506ms/step - loss: 0.2620 - accuracy: 0.8947 - val_loss: 0.5856 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 11/20
# 79/79 [==============================] - 40s 507ms/step - loss: 0.2477 - accuracy: 0.8967 - val_loss: 0.4876 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 12/20
# 79/79 [==============================] - 40s 515ms/step - loss: 0.2232 - accuracy: 0.9151 - val_loss: 0.4820 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 13/20
# 79/79 [==============================] - 40s 509ms/step - loss: 0.2293 - accuracy: 0.9115 - val_loss: 0.4731 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 14/20
# 79/79 [==============================] - 40s 506ms/step - loss: 0.2230 - accuracy: 0.9087 - val_loss: 0.4660 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 15/20
# 79/79 [==============================] - 40s 517ms/step - loss: 0.2174 - accuracy: 0.9135 - val_loss: 0.4869 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 16/20
# 79/79 [==============================] - 40s 512ms/step - loss: 0.1972 - accuracy: 0.9274 - val_loss: 0.4919 - val_accuracy: 0.8229 - lr: 5.0000e-05
# Epoch 17/20
# 79/79 [==============================] - 39s 496ms/step - loss: 0.1818 - accuracy: 0.9290 - val_loss: 0.4775 - val_accuracy: 0.8021 - lr: 5.0000e-05
# Epoch 18/20
# 79/79 [==============================] - 41s 522ms/step - loss: 0.1820 - accuracy: 0.9330 - val_loss: 0.4992 - val_accuracy: 0.8229 - lr: 5.0000e-05
# Epoch 19/20
# 79/79 [==============================] - 40s 508ms/step - loss: 0.1912 - accuracy: 0.9258 - val_loss: 0.4578 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 20/20
# 79/79 [==============================] - 40s 513ms/step - loss: 0.1758 - accuracy: 0.9346 - val_loss: 0.4727 - val_accuracy: 0.7917 - lr: 5.0000e-05
# Initial training complete.
# Unfreezing last 10 layers for fine-tuning...
# Starting fine-tuning...
# Epoch 1/10
# 79/79 [==============================] - 44s 516ms/step - loss: 0.2204 - accuracy: 0.9062 - val_loss: 0.4262 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 2/10
# 79/79 [==============================] - 39s 499ms/step - loss: 0.1689 - accuracy: 0.9386 - val_loss: 0.4203 - val_accuracy: 0.8229 - lr: 1.0000e-05
# Epoch 3/10
# 79/79 [==============================] - 40s 509ms/step - loss: 0.1530 - accuracy: 0.9466 - val_loss: 0.4169 - val_accuracy: 0.8438 - lr: 1.0000e-05
# Epoch 4/10
# 79/79 [==============================] - 40s 503ms/step - loss: 0.1311 - accuracy: 0.9553 - val_loss: 0.4097 - val_accuracy: 0.8229 - lr: 1.0000e-05
# Epoch 5/10
# 79/79 [==============================] - 40s 512ms/step - loss: 0.1277 - accuracy: 0.9585 - val_loss: 0.4161 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 6/10
# 79/79 [==============================] - 40s 508ms/step - loss: 0.1064 - accuracy: 0.9693 - val_loss: 0.4255 - val_accuracy: 0.8542 - lr: 1.0000e-05
# Epoch 7/10
# 79/79 [==============================] - 39s 497ms/step - loss: 0.0958 - accuracy: 0.9725 - val_loss: 0.4191 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 8/10
# 79/79 [==============================] - 41s 524ms/step - loss: 0.0887 - accuracy: 0.9745 - val_loss: 0.4330 - val_accuracy: 0.8229 - lr: 1.0000e-05
# Epoch 9/10
# 79/79 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9837
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 79/79 [==============================] - 39s 504ms/step - loss: 0.0739 - accuracy: 0.9837 - val_loss: 0.4308 - val_accuracy: 0.8229 - lr: 1.0000e-05
# Epoch 10/10
# 79/79 [==============================] - 40s 512ms/step - loss: 0.0689 - accuracy: 0.9864 - val_loss: 0.4284 - val_accuracy: 0.8229 - lr: 5.0000e-06
# Fine-tuning complete.

# %%
#Cell 2: Validation & Metrics Visualization
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# Evaluate on full validation set
print("Evaluating on validation set...")
val_preds_prob = model.predict(valid_gen, steps=valid_steps, verbose=1)
val_preds = (val_preds_prob > 0.5).astype(int).flatten()

val_true = valid_gen.classes[:len(val_preds)]  # Make sure lengths match
val_filenames = valid_gen.filenames[:len(val_preds)]
class_names = list(valid_gen.class_indices.keys())

print(f"Validation samples: {len(val_true)}")
print(f"Correct predictions: {(val_preds == val_true).sum()}")
print(f"Wrong predictions: {(val_preds != val_true).sum()}")

# Confusion matrix
cm = confusion_matrix(val_true, val_preds)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(val_true, val_preds, target_names=class_names))

# ROC Curve
fpr, tpr, _ = roc_curve(val_true, val_preds_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.3f}')
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Plot examples of correct and wrong predictions
def plot_examples(indices, title, max_imgs=10):
    plt.figure(figsize=(20,4))
    for i, idx in enumerate(indices[:max_imgs]):
        img_path = os.path.join(valid_dir, val_filenames[idx])
        img = plt.imread(img_path)
        plt.subplot(1, max_imgs, i+1)
        plt.imshow(img)
        plt.title(f"Pred: {class_names[val_preds[idx]]}\nTrue: {class_names[val_true[idx]]}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

correct_idx = np.where(val_preds == val_true)[0]
wrong_idx = np.where(val_preds != val_true)[0]

plot_examples(correct_idx, "Correct Predictions")
plot_examples(wrong_idx, "Wrong Predictions")
# Out:
# Evaluating on validation set...
# 3/3 [==============================] - 1s 177ms/step
# Validation samples: 96
# Correct predictions: 79
# Wrong predictions: 17
# Classification Report:
#               precision    recall  f1-score   support
#
#     Autistic       0.81      0.86      0.83        50
# Non_Autistic       0.84      0.78      0.81        46
#
#     accuracy                           0.82        96
#    macro avg       0.82      0.82      0.82        96
# weighted avg       0.82      0.82      0.82        96

# %%
#Cell 3: Test Predictions and Single Image Inference
test_dir = './test'  # Folder with unlabeled test images
test_filenames = os.listdir(test_dir)
test_df = pd.DataFrame({'filename': test_filenames})

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_gen = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=test_dir,
    x_col='filename',
    y_col=None,
    target_size=img_size,
    batch_size=1,
    class_mode=None,
    shuffle=False
)

print("Predicting on test set...")
test_preds_prob = model.predict(test_gen, verbose=1)
test_preds = (test_preds_prob > 0.5).astype(int).flatten()

print("\nTest Predictions:")
for fname, pred in zip(test_gen.filenames, test_preds):
    label = 'Autistic' if pred == 0 else 'Non_Autistic'
    print(f"{fname}: {label}")

# Single image prediction helper
def predict_image(img_path):
    img = detect_and_crop_face(img_path)
    if img is None:
        print("No face detected, resizing full image")
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
    x = np.expand_dims(img, axis=0)
    x = preprocess_input(x.astype(np.float32))
    pred_prob = model.predict(x)[0][0]
    pred_label = 'Autistic' if pred_prob < 0.5 else 'Non_Autistic'
    print(f"Prediction: {pred_label} (Confidence: {pred_prob:.3f})")
    plt.imshow(img)
    plt.title(f"Predicted: {pred_label}")
    plt.axis('off')
    plt.show()

# Example usage:
# predict_image('path/to/single/image.jpg')
# Out:
# Found 300 validated image filenames.
# Predicting on test set...
# 300/300 [==============================] - 5s 9ms/step
#
# Test Predictions:
# Autistic.0.jpg: Autistic
# Autistic.1.jpg: Autistic
# Autistic.10.jpg: Autistic
# Autistic.100.jpg: Autistic
# Autistic.101.jpg: Autistic
# Autistic.102.jpg: Autistic
# Autistic.103.jpg: Autistic
# Autistic.104.jpg: Autistic
# Autistic.105.jpg: Autistic
# Autistic.106.jpg: Autistic
# Autistic.107.jpg: Non_Autistic
# Autistic.108.jpg: Non_Autistic
# Autistic.109.jpg: Autistic
# Autistic.11.jpg: Autistic
# Autistic.110.jpg: Autistic
# Autistic.111.jpg: Autistic
# Autistic.112.jpg: Autistic
# Autistic.113.jpg: Autistic
# Autistic.114.jpg: Autistic
# Autistic.115.jpg: Non_Autistic
# Autistic.116.jpg: Autistic
# Autistic.117.jpg: Autistic
# Autistic.118.jpg: Autistic
# Autistic.119.jpg: Autistic
# Autistic.12.jpg: Non_Autistic
# Autistic.120.jpg: Autistic
# Autistic.121.jpg: Autistic
# Autistic.122.jpg: Autistic
# Autistic.123.jpg: Autistic
# Autistic.124.jpg: Autistic
# Autistic.125.jpg: Autistic
# Autistic.126.jpg: Autistic
# Autistic.127.jpg: Autistic
# Autistic.128.jpg: Autistic
# Autistic.129.jpg: Autistic
# Autistic.13.jpg: Autistic
# Autistic.130.jpg: Autistic
# Autistic.131.jpg: Autistic
# Autistic.132.jpg: Autistic
# Autistic.133.jpg: Non_Autistic
# Autistic.134.jpg: Autistic
# Autistic.135.jpg: Autistic
# Autistic.136.jpg: Autistic
# Autistic.137.jpg: Autistic
# Autistic.138.jpg: Autistic
# Autistic.139.jpg: Autistic
# Autistic.14.jpg: Autistic
# Autistic.140.jpg: Autistic
# Autistic.141.jpg: Autistic
# Autistic.142.jpg: Autistic
# Autistic.143.jpg: Autistic
# Autistic.144.jpg: Autistic
# Autistic.145.jpg: Autistic
# Autistic.146.jpg: Autistic
# Autistic.147.jpg: Non_Autistic
# Autistic.148.jpg: Autistic
# Autistic.149.jpg: Autistic
# Autistic.15.jpg: Autistic
# Autistic.16.jpg: Non_Autistic
# Autistic.17.jpg: Autistic
# Autistic.18.jpg: Autistic
# Autistic.19.jpg: Autistic
# Autistic.2.jpg: Autistic
# Autistic.20.jpg: Autistic
# Autistic.21.jpg: Autistic
# Autistic.22.jpg: Autistic
# Autistic.23.jpg: Autistic
# Autistic.24.jpg: Autistic
# Autistic.25.jpg: Non_Autistic
# Autistic.26.jpg: Autistic
# Autistic.27.jpg: Autistic
# Autistic.28.jpg: Autistic
# Autistic.29.jpg: Autistic
# Autistic.3.jpg: Autistic
# Autistic.30.jpg: Non_Autistic
# Autistic.31.jpg: Autistic
# Autistic.32.jpg: Autistic
# Autistic.33.jpg: Autistic
# Autistic.34.jpg: Autistic
# Autistic.35.jpg: Autistic
# Autistic.36.jpg: Autistic
# Autistic.37.jpg: Non_Autistic
# Autistic.38.jpg: Autistic
# Autistic.39.jpg: Autistic
# Autistic.4.jpg: Autistic
# Autistic.40.jpg: Autistic
# Autistic.41.jpg: Autistic
# Autistic.42.jpg: Autistic
# Autistic.43.jpg: Autistic
# Autistic.44.jpg: Autistic
# Autistic.45.jpg: Autistic
# Autistic.46.jpg: Autistic
# Autistic.47.jpg: Autistic
# Autistic.48.jpg: Autistic
# Autistic.49.jpg: Autistic
# Autistic.5.jpg: Autistic
# Autistic.50.jpg: Autistic
# Autistic.51.jpg: Autistic
# Autistic.52.jpg: Autistic
# Autistic.53.jpg: Autistic
# Autistic.54.jpg: Autistic
# Autistic.55.jpg: Autistic
# Autistic.56.jpg: Autistic
# Autistic.57.jpg: Autistic
# Autistic.58.jpg: Non_Autistic
# Autistic.59.jpg: Autistic
# Autistic.6.jpg: Autistic
# Autistic.60.jpg: Autistic
# Autistic.61.jpg: Autistic
# Autistic.62.jpg: Autistic
# Autistic.63.jpg: Autistic
# Autistic.64.jpg: Non_Autistic
# Autistic.65.jpg: Autistic
# Autistic.66.jpg: Autistic
# Autistic.67.jpg: Non_Autistic
# Autistic.68.jpg: Autistic
# Autistic.69.jpg: Autistic
# Autistic.7.jpg: Autistic
# Autistic.70.jpg: Autistic
# Autistic.71.jpg: Autistic
# Autistic.72.jpg: Autistic
# Autistic.73.jpg: Autistic
# Autistic.74.jpg: Autistic
# Autistic.75.jpg: Autistic
# Autistic.76.jpg: Autistic
# Autistic.77.jpg: Autistic
# Autistic.78.jpg: Autistic
# Autistic.79.jpg: Non_Autistic
# Autistic.8.jpg: Autistic
# Autistic.80.jpg: Autistic
# Autistic.81.jpg: Autistic
# Autistic.82.jpg: Autistic
# Autistic.83.jpg: Autistic
# Autistic.84.jpg: Autistic
# Autistic.85.jpg: Autistic
# Autistic.86.jpg: Non_Autistic
# Autistic.87.jpg: Autistic
# Autistic.88.jpg: Autistic
# Autistic.89.jpg: Autistic
# Autistic.9.jpg: Autistic
# Autistic.90.jpg: Autistic
# Autistic.91.jpg: Autistic
# Autistic.92.jpg: Autistic
# Autistic.93.jpg: Autistic
# Autistic.94.jpg: Autistic
# Autistic.95.jpg: Autistic
# Autistic.96.jpg: Autistic
# Autistic.97.jpg: Autistic
# Autistic.98.jpg: Autistic
# Autistic.99.jpg: Autistic
# Non_Autistic.0.jpg: Non_Autistic
# Non_Autistic.1.jpg: Non_Autistic
# Non_Autistic.10.jpg: Non_Autistic
# Non_Autistic.100.jpg: Non_Autistic
# Non_Autistic.101.jpg: Non_Autistic
# Non_Autistic.102.jpg: Non_Autistic
# Non_Autistic.103.jpg: Non_Autistic
# Non_Autistic.104.jpg: Non_Autistic
# Non_Autistic.105.jpg: Non_Autistic
# Non_Autistic.106.jpg: Autistic
# Non_Autistic.107.jpg: Non_Autistic
# Non_Autistic.108.jpg: Non_Autistic
# Non_Autistic.109.jpg: Non_Autistic
# Non_Autistic.11.jpg: Non_Autistic
# Non_Autistic.110.jpg: Non_Autistic
# Non_Autistic.111.jpg: Autistic
# Non_Autistic.112.jpg: Autistic
# Non_Autistic.113.jpg: Non_Autistic
# Non_Autistic.114.jpg: Non_Autistic
# Non_Autistic.115.jpg: Non_Autistic
# Non_Autistic.116.jpg: Non_Autistic
# Non_Autistic.117.jpg: Non_Autistic
# Non_Autistic.118.jpg: Non_Autistic
# Non_Autistic.119.jpg: Non_Autistic
# Non_Autistic.12.jpg: Autistic
# Non_Autistic.120.jpg: Non_Autistic
# Non_Autistic.121.jpg: Non_Autistic
# Non_Autistic.122.jpg: Non_Autistic
# Non_Autistic.123.jpg: Non_Autistic
# Non_Autistic.124.jpg: Non_Autistic
# Non_Autistic.125.jpg: Non_Autistic
# Non_Autistic.126.jpg: Non_Autistic
# Non_Autistic.127.jpg: Non_Autistic
# Non_Autistic.128.jpg: Non_Autistic
# Non_Autistic.129.jpg: Non_Autistic
# Non_Autistic.13.jpg: Non_Autistic
# Non_Autistic.130.jpg: Non_Autistic
# Non_Autistic.131.jpg: Non_Autistic
# Non_Autistic.132.jpg: Non_Autistic
# Non_Autistic.133.jpg: Autistic
# Non_Autistic.134.jpg: Non_Autistic
# Non_Autistic.135.jpg: Non_Autistic
# Non_Autistic.136.jpg: Non_Autistic
# Non_Autistic.137.jpg: Non_Autistic
# Non_Autistic.138.jpg: Non_Autistic
# Non_Autistic.139.jpg: Non_Autistic
# Non_Autistic.14.jpg: Non_Autistic
# Non_Autistic.140.jpg: Non_Autistic
# Non_Autistic.141.jpg: Non_Autistic
# Non_Autistic.142.jpg: Non_Autistic
# Non_Autistic.143.jpg: Non_Autistic
# Non_Autistic.144.jpg: Non_Autistic
# Non_Autistic.145.jpg: Non_Autistic
# Non_Autistic.146.jpg: Non_Autistic
# Non_Autistic.147.jpg: Non_Autistic
# Non_Autistic.148.jpg: Non_Autistic
# Non_Autistic.149.jpg: Non_Autistic
# Non_Autistic.15.jpg: Non_Autistic
# Non_Autistic.16.jpg: Non_Autistic
# Non_Autistic.17.jpg: Non_Autistic
# Non_Autistic.18.jpg: Non_Autistic
# Non_Autistic.19.jpg: Autistic
# Non_Autistic.2.jpg: Non_Autistic
# Non_Autistic.20.jpg: Non_Autistic
# Non_Autistic.21.jpg: Non_Autistic
# Non_Autistic.22.jpg: Autistic
# Non_Autistic.23.jpg: Non_Autistic
# Non_Autistic.24.jpg: Autistic
# Non_Autistic.25.jpg: Non_Autistic
# Non_Autistic.26.jpg: Autistic
# Non_Autistic.27.jpg: Non_Autistic
# Non_Autistic.28.jpg: Non_Autistic
# Non_Autistic.29.jpg: Non_Autistic
# Non_Autistic.3.jpg: Autistic
# Non_Autistic.30.jpg: Non_Autistic
# Non_Autistic.31.jpg: Non_Autistic
# Non_Autistic.32.jpg: Non_Autistic
# Non_Autistic.33.jpg: Non_Autistic
# Non_Autistic.34.jpg: Non_Autistic
# Non_Autistic.35.jpg: Non_Autistic
# Non_Autistic.36.jpg: Non_Autistic
# Non_Autistic.37.jpg: Non_Autistic
# Non_Autistic.38.jpg: Non_Autistic
# Non_Autistic.39.jpg: Non_Autistic
# Non_Autistic.4.jpg: Non_Autistic
# Non_Autistic.40.jpg: Non_Autistic
# Non_Autistic.41.jpg: Non_Autistic
# Non_Autistic.42.jpg: Non_Autistic
# Non_Autistic.43.jpg: Non_Autistic
# Non_Autistic.44.jpg: Non_Autistic
# Non_Autistic.45.jpg: Non_Autistic
# Non_Autistic.46.jpg: Autistic
# Non_Autistic.47.jpg: Non_Autistic
# Non_Autistic.48.jpg: Non_Autistic
# Non_Autistic.49.jpg: Autistic
# Non_Autistic.5.jpg: Autistic
# Non_Autistic.50.jpg: Autistic
# Non_Autistic.51.jpg: Non_Autistic
# Non_Autistic.52.jpg: Autistic
# Non_Autistic.53.jpg: Non_Autistic
# Non_Autistic.54.jpg: Non_Autistic
# Non_Autistic.55.jpg: Autistic
# Non_Autistic.56.jpg: Non_Autistic
# Non_Autistic.57.jpg: Non_Autistic
# Non_Autistic.58.jpg: Non_Autistic
# Non_Autistic.59.jpg: Non_Autistic
# Non_Autistic.6.jpg: Non_Autistic
# Non_Autistic.60.jpg: Non_Autistic
# Non_Autistic.61.jpg: Non_Autistic
# Non_Autistic.62.jpg: Non_Autistic
# Non_Autistic.63.jpg: Autistic
# Non_Autistic.64.jpg: Autistic
# Non_Autistic.65.jpg: Non_Autistic
# Non_Autistic.66.jpg: Non_Autistic
# Non_Autistic.67.jpg: Autistic
# Non_Autistic.68.jpg: Non_Autistic
# Non_Autistic.69.jpg: Non_Autistic
# Non_Autistic.7.jpg: Non_Autistic
# Non_Autistic.70.jpg: Non_Autistic
# Non_Autistic.71.jpg: Autistic
# Non_Autistic.72.jpg: Autistic
# Non_Autistic.73.jpg: Autistic
# Non_Autistic.74.jpg: Non_Autistic
# Non_Autistic.75.jpg: Non_Autistic
# Non_Autistic.76.jpg: Autistic
# Non_Autistic.77.jpg: Non_Autistic
# Non_Autistic.78.jpg: Non_Autistic
# Non_Autistic.79.jpg: Non_Autistic
# Non_Autistic.8.jpg: Autistic
# Non_Autistic.80.jpg: Non_Autistic
# Non_Autistic.81.jpg: Non_Autistic
# Non_Autistic.82.jpg: Non_Autistic
# Non_Autistic.83.jpg: Autistic
# Non_Autistic.84.jpg: Autistic
# Non_Autistic.85.jpg: Non_Autistic
# Non_Autistic.86.jpg: Autistic
# Non_Autistic.87.jpg: Non_Autistic
# Non_Autistic.88.jpg: Non_Autistic
# Non_Autistic.89.jpg: Non_Autistic
# Non_Autistic.9.jpg: Non_Autistic
# Non_Autistic.90.jpg: Autistic
# Non_Autistic.91.jpg: Non_Autistic
# Non_Autistic.92.jpg: Non_Autistic
# Non_Autistic.93.jpg: Non_Autistic
# Non_Autistic.94.jpg: Non_Autistic
# Non_Autistic.95.jpg: Autistic
# Non_Autistic.96.jpg: Autistic
# Non_Autistic.97.jpg: Non_Autistic
# Non_Autistic.98.jpg: Non_Autistic
# Non_Autistic.99.jpg: Non_Autistic
